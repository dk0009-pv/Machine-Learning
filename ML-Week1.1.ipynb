# %%
# In Lab

print("Hello World")
print("My name is DINESH KUMAR")
# Out:
# Hello World
# My name is DINESH KUMAR

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Enter first number: 20
# Enter second number: 10
# Addition: 30
# Subtraction: 10
# Multiplication: 200
# Division: 2.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Load dataset
data = pd.read_csv("/content/drive/MyDrive/Machine Learning/student_data.csv")
#data = pd.read_csv("student_data.csv")

# %%
print(data.head())
# Out:
#    RollNo  Math  Science  English  Gender Department
# 0       1    55       58       60    Male        CSE
# 1       2    60       63       64  Female        ECE
# 2       3    65       68       69    Male        EEE
# 3       4    70       73       74  Female        CSE
# 4       5    75       78       80    Male        ECE

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RollNo      50 non-null     int64
#  1   Math        50 non-null     int64
#  2   Science     50 non-null     int64
#  3   English     50 non-null     int64
#  4   Gender      50 non-null     object
#  5   Department  50 non-null     object
# dtypes: int64(4), object(2)
# memory usage: 2.5+ KB

# %%
print(data.describe())
# Out:
#          RollNo       Math    Science    English
# count  50.00000  50.000000  50.000000  50.000000
# mean   25.50000  65.000000  68.000000  69.400000
# std    14.57738   7.142857   7.142857   7.159979
# min     1.00000  55.000000  58.000000  60.000000
# 25%    13.25000  60.000000  63.000000  64.000000
# 50%    25.50000  65.000000  68.000000  69.000000
# 75%    37.75000  70.000000  73.000000  74.000000
# max    50.00000  75.000000  78.000000  80.000000

# %%
import matplotlib.pyplot as plt

# Example plot
plt.plot(data.index, data[data.columns[0]], label="Column 1")

plt.title("Sample Data Plot")
plt.xlabel("Index")
plt.ylabel("Values")
plt.legend()

plt.show()

# %%
# POST LAB
# 1st Answer

num = int(input("Enter a number: "))
sum_digits = 0

while num > 0:
    digit = num % 10
    sum_digits += digit
    num //= 10

print("Sum of digits:", sum_digits)
# Out:
# Enter a number: 32
# Sum of digits: 5

# %%
 # 2nd Answer

n = int(input("Enter a number: "))

print(f"Multiplication Table of {n}")
for i in range(1, 11):
    print(f"{n} x {i} = {n * i}")
# Out:
# Enter a number: 24
# Multiplication Table of 24
# 24 x 1 = 24
# 24 x 2 = 48
# 24 x 3 = 72
# 24 x 4 = 96
# 24 x 5 = 120
# 24 x 6 = 144
# 24 x 7 = 168
# 24 x 8 = 192
# 24 x 9 = 216
# 24 x 10 = 240

# %%
# 3rd Answer

import matplotlib.pyplot as plt

labels = ['Python', 'Java', 'C++', 'JavaScript']
sizes = [40, 25, 20, 15]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title("Programming Language Usage Distribution")
plt.show()

# %%
# 4th Answer

import pandas as pd
import time

# Method 1: read_csv
start = time.time()
df1 = pd.read_csv("/content/drive/MyDrive/Machine Learning/student_data.csv")
end = time.time()
print("read_csv time:", end - start)

# Method 2: read_table
start = time.time()
df2 = pd.read_table("/content/drive/MyDrive/Machine Learning/student_data.csv", delimiter=",")
end = time.time()
print("read_table time:", end - start)
# Out:
# read_csv time: 0.008323192596435547
# read_table time: 0.004319906234741211

# %%
# 5th Answer

try:
    file = open("sample.txt", "r")
    content = file.read()
    print(content)
    file.close()

except FileNotFoundError:
    print("Error: File not found.")

except IOError:
    print("Error: Unable to read the file.")

finally:
    print("File operation completed.")
# Out:
# Error: File not found.
# File operation completed.
